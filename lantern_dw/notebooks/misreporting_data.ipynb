# %%
import duckdb

# %%
db_path = '/workspaces/dw-lantern/lantern_dw/transactions.duckdb'

# %%
conn = duckdb.connect(db_path)

df = conn.execute("select * from company_performance_validation").fetchdf()

df
# Out:
#     company_id    company year_quarter  actual_sales_amount  \
# 0            2   ModuGear      2024_q1             148230.0
# 1            2   ModuGear      2024_q2             128790.0
# 2            2   ModuGear      2024_q3             102870.0
# 3            2   ModuGear      2024_q4              44550.0
# 4            1  FreshByte      2024_q1              68352.0
# 5            1  FreshByte      2024_q2             110592.0
# 6            1  FreshByte      2024_q3             181248.0
# 7            1  FreshByte      2024_q4             197376.0
# 8            4   OmniCorp      2024_q1             173600.0
# 9            4   OmniCorp      2024_q2             190400.0
# 10           4   OmniCorp      2024_q3             175000.0
# 11           4   OmniCorp      2024_q4             188300.0
# 12           5  TitanTech      2024_q1             210750.0
# 13           5  TitanTech      2024_q2             201000.0
# 14           5  TitanTech      2024_q3             207000.0
# ...
