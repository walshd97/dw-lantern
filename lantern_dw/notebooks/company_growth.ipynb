# %%
import duckdb

# %%
db_path = '/workspaces/dw-lantern/lantern_dw/transactions.duckdb'

# %%
conn = duckdb.connect(db_path)

df = conn.execute("select * from '02_company_growth'").fetchdf()

df
# Out:
#     company_id    company quarter_start_date  sales_amount  sales_growth  \
# 0            1  FreshByte         2024-01-01       68352.0           NaN
# 1            1  FreshByte         2024-04-01      110592.0         61.80
# 2            1  FreshByte         2024-07-01      181248.0         63.89
# 3            1  FreshByte         2024-10-01      197376.0          8.90
# 4            2   ModuGear         2024-01-01      148230.0           NaN
# 5            2   ModuGear         2024-04-01      128790.0        -13.11
# 6            2   ModuGear         2024-07-01      102870.0        -20.13
# 7            2   ModuGear         2024-10-01       44550.0        -56.69
# 8            3  NanoBuild         2024-01-01       62322.0           NaN
# 9            3  NanoBuild         2024-04-01      125443.0        101.28
# 10           3  NanoBuild         2024-07-01      180574.0         43.95
# 11           3  NanoBuild         2024-10-01      210936.0         16.81
# 12           4   OmniCorp         2024-01-01      173600.0           NaN
# 13           4   OmniCorp         2024-04-01      190400.0          9.68
# 14           4   OmniCorp         2024-07-01      175000.0         -8.09
# 15           4   OmniCorp         2024-10-01      188300.0          7.60
# 16           5  TitanTech         2024-01-01      210750.0           NaN
# 17           5  TitanTech         2024-04-01      201000.0         -4.63
# 18           5  TitanTech         2024-07-01      207000.0          2.99
# 19           5  TitanTech         2024-10-01      218250.0          5.43
#
#     total_profit  profit_growth
# 0        22632.0            NaN
# 1        38472.0          23.17
# 2        64488.0          23.52
# 3        71496.0           3.87
# 4        23430.0            NaN
# 5        18390.0          -3.40
# 6        11670.0          -5.22
# 7        -3450.0         -14.70
# 8        23262.0            NaN
# 9        49253.0          41.70
# 10       65374.0          12.85
# 11       89156.0          13.17
# 12       22200.0            NaN
# 13       40500.0          10.54
# 14       37100.0          -1.79
# 15       47400.0           5.89
# 16       42750.0            NaN
# 17       52500.0           4.63
# 18       49500.0          -1.49
# 19       58750.0           4.47
