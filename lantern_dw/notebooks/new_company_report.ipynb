# %%
import duckdb

# %%
db_path = '/workspaces/dw-lantern/lantern_dw/transactions.duckdb'

# %%
conn = duckdb.connect(db_path)

df = conn.execute("select * from '02_updated_company_report'").fetchdf()

display(df)

conn.close()
# Out:
#     company_id         company quarter_start_date  sales_amount  \
# 0            2        ModuGear         2025-01-01       12960.0
# 1            1       FreshByte         2024-01-01       68352.0
# 2            1       FreshByte         2024-04-01      110592.0
# 3            1       FreshByte         2024-07-01      181248.0
# 4            1       FreshByte         2024-10-01      197376.0
# 5            4        OmniCorp         2024-01-01      173600.0
# 6            4        OmniCorp         2024-04-01      190400.0
# 7            4        OmniCorp         2024-07-01      175000.0
# 8            4        OmniCorp         2024-10-01      188300.0
# 9            5  The Titan Tech         2024-01-01      210750.0
# 10           5  The Titan Tech         2024-04-01      201000.0
# 11           5  The Titan Tech         2024-07-01      207000.0
# 12           5  The Titan Tech         2024-10-01      218250.0
# 13           3       NanoBuild         2024-01-01       62322.0
# ...
